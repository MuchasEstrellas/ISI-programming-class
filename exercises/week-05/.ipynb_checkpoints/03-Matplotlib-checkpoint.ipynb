# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt

#when you use jupyter notebook.
# %matplotlib inline

# %% [markdown]
# ## 1. Basic

# %%
import numpy as np
x = np.linspace(1, 10, 50) #n
a = np.log(x) #logn
b = x ** 2 #n^2
c = np.log(x)*x #nlogn 
d = 2**x #2^n

# %%
plt.plot(x, a, 'r') # 'r' is the color red
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Title')
plt.show()

# %%
# plt.subplot(nrows, ncols, plot_number)
plt.subplot(1,3,1)
plt.plot(x, b, 'r*-');
plt.subplot(1,3,2)
plt.plot(x, c, 'b--');
plt.subplot(1,3,3)
plt.plot(x, d, 'g+-');

#What's this?
plt.tight_layout()

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, a, label="logN")
ax.plot(x, b, label="N^2")
ax.plot(x, c, label="NlogN")
ax.plot(x, d, label="2^N")
ax.legend()

# %%
fig = plt.figure()

ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.1,0.4,0.3,0.3])

ax1.plot(x, a, label="logN")
ax1.plot(x, b, label="N^2")
ax1.legend()

ax2.plot(x, c, label="NlogN")
ax2.plot(x, d, label="2^N")
ax2.legend()

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, a, label="logN")
ax.plot(x, b, label="N^2")
ax.plot(x, c, label="NlogN")
ax.plot(x, d, label="2^N")
ax.set_ylim([0,100])
ax.legend()

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.set_title("Title")
ax.plot(x, a, label="logN")
ax.plot(x, b, label="N^2")
ax.plot(x, c, label="NlogN")
ax.plot(x, d, label="2^N")
ax.set_ylim([0,100])
ax.set_xlim([3,7])
ax.legend()

# %% [markdown]
# ### 2. Other plots

# %% [markdown]
# Code can be found from [here](https://matplotlib.org/gallery/index.html)

# %%
plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

ax.barh(y_pos, performance, xerr=error, align='center',
        color='green', ecolor='black')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('How fast do you want to go today?')

plt.show()

# %%
fig, ax = plt.subplots()
for color in ['red', 'green', 'blue']:
    n = 750
    x, y = np.random.rand(2, n)
    scale = 200.0 * np.random.rand(n)
    ax.scatter(x, y, c=color, s=scale, label=color,
               alpha=0.3, edgecolors='none')

ax.legend()
ax.grid(True)

plt.show()

# %%
N_points = 100000
n_bins = 20

# Generate a normal distribution, center at x=0 and y=5
x = np.random.randn(N_points)
y = .4 * x + np.random.randn(100000) + 5

fig, axs = plt.subplots(1, 2, sharey=True)

# We can set the number of bins with the `bins` kwarg
axs[0].hist(x, bins=n_bins)
axs[1].hist(y, bins=n_bins)
# Out:
# (array([4.0000e+00, 1.3000e+01, 9.9000e+01, 3.4200e+02, 1.0230e+03,
#         2.4330e+03, 5.2290e+03, 8.8520e+03, 1.3211e+04, 1.6209e+04,
#         1.6490e+04, 1.4404e+04, 1.0325e+04, 6.2470e+03, 3.1620e+03,
#         1.3340e+03, 4.4500e+02, 1.5800e+02, 1.7000e+01, 3.0000e+00]),
#  array([0.36237721, 0.81866362, 1.27495003, 1.73123644, 2.18752285,
#         2.64380926, 3.10009567, 3.55638208, 4.01266849, 4.4689549 ,
#         4.92524131, 5.38152772, 5.83781413, 6.29410054, 6.75038695,
#         7.20667336, 7.66295977, 8.11924618, 8.57553259, 9.03181899,
#         9.4881054 ]),
#  <a list of 20 Patch objects>)
