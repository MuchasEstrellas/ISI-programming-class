# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt

#when you use jupyter notebook.
# %matplotlib inline

# %% [markdown]
# ## 1. Basic

# %%
import numpy as np
x = np.linspace(1, 10, 50) #n
a = np.log(x) #logn
b = x ** 2 #n^2
c = np.log(x)*x #nlogn 
d = 2**x #2^n

# %%
plt.plot(x, a, 'r') # 'r' is the color red
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Title')
plt.show()

# %%
# plt.subplot(nrows, ncols, plot_number)
plt.subplot(1,3,1)
plt.plot(x, b, 'r*-');
plt.subplot(1,3,2)
plt.plot(x, c, 'b--');
plt.subplot(1,3,3)
plt.plot(x, d, 'g+-');

#What's this?
plt.tight_layout()

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, a, label="logN")
ax.plot(x, b, label="N^2")
ax.plot(x, c, label="NlogN")
ax.plot(x, d, label="2^N")
ax.legend()

# %%
fig = plt.figure()

ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.1,0.4,0.3,0.3])

ax1.plot(x, a, label="logN")
ax1.plot(x, b, label="N^2")
ax1.legend()

ax2.plot(x, c, label="NlogN")
ax2.plot(x, d, label="2^N")
ax2.legend()

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, a, label="logN")
ax.plot(x, b, label="N^2")
ax.plot(x, c, label="NlogN")
ax.plot(x, d, label="2^N")
ax.set_ylim([0,100])
ax.legend()

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.set_title("Title")
ax.plot(x, a, label="logN")
ax.plot(x, b, label="N^2")
ax.plot(x, c, label="NlogN")
ax.plot(x, d, label="2^N")
ax.set_ylim([0,100])
ax.set_xlim([3,7])
ax.legend()

# %% [markdown]
# ### 2. Other plots

# %% [markdown]
# Code can be found from [here](https://matplotlib.org/gallery/index.html)

# %%
plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
people = ['Tom', 'Dick', 'Harry', 'Slim', 'Jim']
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

ax.barh(y_pos, performance, xerr=error, align='center',
        color='green', ecolor='black')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('How fast do you want to go today?')

plt.show()

# %%
fig, ax = plt.subplots()
for color in ['red', 'green', 'blue']:
    n = 750
    x, y = np.random.rand(2, n)
    scale = 200.0 * np.random.rand(n)
    ax.scatter(x, y, c=color, s=scale, label=color,
               alpha=0.3, edgecolors='none')

ax.legend()
ax.grid(True)

plt.show()

# %%
N_points = 100000
n_bins = 20

# Generate a normal distribution, center at x=0 and y=5
x = np.random.randn(N_points)
y = .4 * x + np.random.randn(100000) + 5

fig, axs = plt.subplots(1, 2, sharey=True)

# We can set the number of bins with the `bins` kwarg
axs[0].hist(x, bins=n_bins)
axs[1].hist(y, bins=n_bins)
# Out:
# (array([1.6000e+01, 5.9000e+01, 2.0600e+02, 6.3800e+02, 1.7310e+03,
#         3.6900e+03, 6.8610e+03, 1.0912e+04, 1.4509e+04, 1.6165e+04,
#         1.5326e+04, 1.2443e+04, 8.5320e+03, 4.9930e+03, 2.3960e+03,
#         1.0350e+03, 3.6700e+02, 8.4000e+01, 3.1000e+01, 6.0000e+00]),
#  array([0.690801  , 1.1347248 , 1.5786486 , 2.0225724 , 2.46649619,
#         2.91041999, 3.35434379, 3.79826758, 4.24219138, 4.68611518,
#         5.13003898, 5.57396277, 6.01788657, 6.46181037, 6.90573416,
#         7.34965796, 7.79358176, 8.23750556, 8.68142935, 9.12535315,
#         9.56927695]),
#  <a list of 20 Patch objects>)
